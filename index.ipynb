# %%
import gensim
from gensim import corpora
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import pdfplumber as pdp
import fitz 
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# %%
def pdf_to_text(pdf_path):
    text = ""
    with pdp.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

# Example usage
pdf_text = pdf_to_text("unlabelled\Resume_2.pdf")

# Print the extracted text
print(pdf_text)
# Out:
# Resume
# Name : Nirmal Cardoza
# ​
# Email : nirmal.cardoza@gmail.com
# ​
# Phone : 9972169059 Hyderabad, India
# Objective:
# To get a Technical Artist role to share and improve my technical and creative skills. And
# to contribute those skills to a good and great game.
# About me:
# I am a passionate gamer wanting to work with a team to make quality games , and eager
# to learn and share skills and knowledge. I have a good artistic sense as well as knowledge to
# see Art Technically, as I evolved from an 3d artist to Technical Artist. And I love to discuss
# games and make prototypes.
# Skills:
# ● Strong experience in Unity Engine.
# ● Skilled to create Tools, Shaders,VFX and Game Prototypes.
# ● Scripts/Programing : C#, Python, MEL, C++
# ● Good understanding of game engines, rendering pipelines, and worked on
# Unity NintendoWare,Vicious Engine , Phyre Engine and Cocos2d
# ● Skilled with Tools for Maya, Rigging, Animation , Fx, and Lighting
# ● Strong problem solving, troubleshooting skills and habit to keep myself learning
# new.
# Job history:
# Glu (May 2018-Present) - Senior Technical/VFX Artist
# Disney Sorcerer's Arena :
# ● Worked on Environment VFX.
# ● Art tool support in Maya and Unity.
# ● Improve and adapt new existing VFX in the game.
# Deer Hunter 2018:
# ● Creating and optimizing all VFX in the game.
# ● Creating new Shaders for new requirements and optimizing or upgrading existing
# shaders.
# ● Tools and scripts in Unity and Maya
# ● Getting Weapon Art content from the team into Unity Engine and setting up
# necessary things for Designers to configure in the Game.Electronic Arts (September 2015- April 2018) - Technical Artist.
# Tetris Blitz 2016 Edition:
# (Update from older game engine to Cocos2d with new feature and UX changes)
# ​ ​
# ● Responsible for getting Art content form team into Cocos2d and setting up the
# scenes for functionality.
# ● Mentoring team for art implementation and optimization.
# ● Created batch tools to process art,optimization/Clean-up.
# ● Solved several problems during the UI engine migration.
# ​ ​
# ● Creating Vfx and animation for the game.
# Plants vs Zombies:
# Worked on the game along with Engineers to research and understand the game
# ​
# to migrate the game to Cocos2d with Cocos Creator as Game Editor.
# Jumpstart / Knowledge Adventure (October 2012 - September 2015) - Technical
# Developer.
# Responsibilities:
# ● Delivering the game apps (iOS , Android , Amazon, Windows Store,Facebook)
# for QA.
# ● UI integration/Setup using NGui in Unity.
# ● Debugging issues in the builds and resolving.
# ● Final Submissions builds for the store (iOS , Android , Amazon, Windows
# Store,Facebook).
# ● Editor tools for the Build pipeline ,building UI and Shader and art optimizations.
# ● Build automation with Jenkins and Unity editor.
# Worked on the following games, (All games are created in Unity3d)
# ● www.jumpstart.com/mobileapps/
# ● www.Mathblaster.com
# ● www.SchoolOfDragons.com
# ​
# GameShastra Solutions Pvt. Ltd (February 2008 – September 2012 ) – Technical Artist.
# ​
# Started my career as 3d artist and then changed my interest to Tech art.
# Worked on Mobile, PSP, PS2 and PS3 platforms.
# Responsibilities:
# ● Created VFX, art optimizations (Mobile and PS platforms)
# ​ ​ ​
# ● Character rigs and other technical art .
# ● R&D with programmers.
# ● Art pipeline R&D on AirPlay, Unity, Viscous, Phyre and Infernal
# ● Tools in Maya (Level editing , track builder etc)Personal Work / Prototypes:
# ​ ​ ​ ​
# Stay (PC / Browser) http://www.nirmalcardoza.com/Stay/stayGame.html
# ​ ​
# Created a browser game for Unity game contest. Got a decent rating with 3/5.
# Responsible for the game design , art and Fx in the game.
# Elemental (PC / Browser) http://www.nirmalcardoza.com/eleMental/eleMental.html
# ​
# Created a browser game for Unity game contest . The topic was Do no harm.
# Responsible for Design, Art and Sound.
# Turn Based Tetris:
# Developed a turn Based game based on Tetris by myself. (Table top 2 player game)-
# https://drive.google.com/open?id=0B2icVX2cdvfzSUdHWXB0d1N6Z0k
# Other
# Access Phone Camera to animate expressions with sequences of snaps in real time.
# Other Ongoing Personal Learnings:
# Blender, Substance Designer, Unreal Engine, Unity(new features)
# Education:
# Diploma in Animation Engineering(DAE) at Aptech -Arena Multimedia, Chennai, India
# LinkedIn:
# https://www.linkedin.com/pub/nirmal-cardoza/9/78/bb3

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

# Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state  # Last layer hidden-states of the model
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask  # Take average

# Compute cosine similarity
def cosine_similarity(embedding1, embedding2):
    return np.dot(embedding1, embedding2) / (np.linalg.norm(embedding1) * np.linalg.norm(embedding2))

def update_highlighting(file_path, output_path, query_text):
    doc = fitz.open(file_path)
    for page_num in range(len(doc)):
        page = doc[page_num]
        page.clean_contents()
        # Tokenize context text
        context_text = page.get_text()
        context_tokens = context_text.lower().split()  # Convert context to lowercase and split into tokens
        query_tok = query_text.lower().split()
        context_tokens = [token for token in context_tokens if token not in query_tok]
        # Compute embeddings for context tokens
        context_input = tokenizer(context_tokens, return_tensors='pt', padding=True, truncation=True)
        with torch.no_grad():
            context_output = model(**context_input)

        # Perform mean pooling
        context_embeddings = mean_pooling(context_output, context_input['attention_mask'])

        # Compute embeddings for query text
        query_input = tokenizer(query_text, return_tensors='pt')
        with torch.no_grad():
            query_output = model(**query_input)

        # Compute mean pooling for query text
        query_embedding = mean_pooling(query_output, query_input['attention_mask']).numpy()

        # Compute similarity between query and context tokens
        token_similarity_scores = {}
        for i, token in enumerate(context_tokens):
            token_embedding = context_embeddings[i].numpy()
            similarity = cosine_similarity(query_embedding, token_embedding)
            token_similarity_scores[token] = similarity

        
        sorted_tokens = sorted(token_similarity_scores.items(), key=lambda x: x[1], reverse=True)
        for item in sorted_tokens:
            print(item)
        for idx, (token, similarity) in enumerate(sorted_tokens):
            if idx < 3:
                for inst in page.search_for(token):
                    page.draw_rect(inst, color=(1, 0.647, 0), fill=(1, 0.9, 0.7), width=1.5, overlay=False)
            elif idx < 6:
                for inst in page.search_for(token):
                    page.draw_rect(inst, color=(1, 1, 0), fill=(1, 1, 0.9), width=1.5, overlay=False)
            elif idx < 10:
                for inst in page.search_for(token):
                    page.draw_rect(inst, color=(1, 1, 0), fill=(1, 1, 0.8), width=1.5, overlay=False)

    doc.save(output_path)

# Open Source
# AI 

# Three dimensional modeling
# Creativity

# Office work
# Discounts

# Innovation
# Leadership experience


# harshibars-resume  
# linkedin_resume_original
# modular-resume
# sales-resume
input_file = "demo\harshibars-resume.pdf"  # Please pass the path to the input PDF
output_file = "out_put_resume2.pdf"  # To be decided by you
query_text = "AI"  # Your query text here

update_highlighting(input_file, output_file, query_text)

output_file
# Out:
# ('algorithms,', array([0.54972625], dtype=float32))
# ('machine', array([0.48757645], dtype=float32))
# ('python,', array([0.47610655], dtype=float32))
# ('python', array([0.46388483], dtype=float32))
# ('software', array([0.4595851], dtype=float32))
# ('arts', array([0.44606185], dtype=float32))
# ('tech', array([0.43967134], dtype=float32))
# ('computer', array([0.42757732], dtype=float32))
# ('learning', array([0.42133367], dtype=float32))
# ('engineer', array([0.4185858], dtype=float32))
# ('ui', array([0.4172641], dtype=float32))
# ('skills', array([0.415241], dtype=float32))
# ('automatically', array([0.4147169], dtype=float32))
# ('systems,', array([0.4126276], dtype=float32))
# ('engineering', array([0.40697452], dtype=float32))
# ('script', array([0.4044734], dtype=float32))
# ('javascript', array([0.40233168], dtype=float32))
# ('java', array([0.3971898], dtype=float32))
# ('analytics,', array([0.39395627], dtype=float32))
# ('languages', array([0.37655282], dtype=float32))
# ('tools', array([0.35563278], dtype=float32))
# ('detect', array([0.3522853], dtype=float32))
# ('databases,', array([0.34861708], dtype=float32))
# ('apps', array([0.34674945], dtype=float32))
# ('future', array([0.3458551], dtype=float32))
# ('science', array([0.34414375], dtype=float32))
# ('database', array([0.33801645], dtype=float32))
# ('education', array([0.33798176], dtype=float32))
# ('productivity', array([0.33723402], dtype=float32))
# ('back-end', array([0.33571306], dtype=float32))
# ('queries', array([0.33302262], dtype=float32))
# ('icons', array([0.3329417], dtype=float32))
# ('android', array([0.3321316], dtype=float32))
# ('process', array([0.3312281], dtype=float32))
# ('input', array([0.3268391], dtype=float32))
# ('google', array([0.322622], dtype=float32))
# ('data', array([0.3214808], dtype=float32))
# ('design', array([0.3208541], dtype=float32))
# ('development', array([0.31690684], dtype=float32))
# ('experience', array([0.31617746], dtype=float32))
# ('trello,', array([0.30730006], dtype=float32))
# ('quality', array([0.30509916], dtype=float32))
# ('control', array([0.3043758], dtype=float32))
# ('feature', array([0.3035572], dtype=float32))
# ('app', array([0.30331105], dtype=float32))
# ('icon', array([0.30141905], dtype=float32))
# ('front-end', array([0.3009141], dtype=float32))
# ('acceptance', array([0.30023682], dtype=float32))
# ('jobs', array([0.2965594], dtype=float32))
# ('production', array([0.2961101], dtype=float32))
# ('users', array([0.29119578], dtype=float32))
# ('lab', array([0.2910962], dtype=float32))
# ('hackaday;', array([0.28749493], dtype=float32))
# ('users,', array([0.28638932], dtype=float32))
# ('mysql)', array([0.2849489], dtype=float32))
# ('consulting', array([0.28489622], dtype=float32))
# ('•', array([0.2823868], dtype=float32))
# ('samples', array([0.2814622], dtype=float32))
# ('apps,', array([0.28021502], dtype=float32))
# ('tool,', array([0.2789402], dtype=float32))
# ('movie', array([0.27874738], dtype=float32))
# ('media', array([0.2766726], dtype=float32))
# ('service', array([0.2740043], dtype=float32))
# ('collaborative', array([0.27269998], dtype=float32))
# ('hackaday', array([0.27162], dtype=float32))
# ('structures,', array([0.2715106], dtype=float32))
# ('testing', array([0.27049196], dtype=float32))
# ('projects', array([0.27036932], dtype=float32))
# ('support', array([0.2644801], dtype=float32))
# ('videos', array([0.2642758], dtype=float32))
# ('from', array([0.26318341], dtype=float32))
# ('a/b', array([0.26121852], dtype=float32))
# ('sql', array([0.26075715], dtype=float32))
# ('using', array([0.2597203], dtype=float32))
# ('search', array([0.2585186], dtype=float32))
# ('customer', array([0.25848266], dtype=float32))
# ('designed', array([0.25733694], dtype=float32))
# ('youtube', array([0.25616205], dtype=float32))
# ('impressions', array([0.2561334], dtype=float32))
# ('creator', array([0.25436473], dtype=float32))
# ('a', array([0.25337914], dtype=float32))
# ('2019', array([0.25234407], dtype=float32))
# ('sales', array([0.25095698], dtype=float32))
# ('ecosystem', array([0.25068685], dtype=float32))
# ('research:', array([0.24919133], dtype=float32))
# ('led', array([0.24873018], dtype=float32))
# ('r/programming', array([0.24828209], dtype=float32))
# ('saving', array([0.24720375], dtype=float32))
# ('at', array([0.24403289], dtype=float32))
# ('problem', array([0.24382733], dtype=float32))
# ('ios', array([0.24301194], dtype=float32))
# ('of', array([0.24289304], dtype=float32))
# ('2018', array([0.24269228], dtype=float32))
# ('davinci', array([0.24261957], dtype=float32))
# ('brands', array([0.24044013], dtype=float32))
# ('workﬂow', array([0.2403461], dtype=float32))
# ('notion,', array([0.23987892], dtype=float32))
# ('suite', array([0.23934172], dtype=float32))
# ('position', array([0.2371638], dtype=float32))
# ('cancer', array([0.23686486], dtype=float32))
# ('titles', array([0.2361136], dtype=float32))
# ('stars', array([0.23482466], dtype=float32))
# ('citizen', array([0.2344079], dtype=float32))
# ('wa', array([0.23355605], dtype=float32))
# ('iterated', array([0.23342085], dtype=float32))
# ('roadmapping;', array([0.23327741], dtype=float32))
# ('(analyzed', array([0.23096454], dtype=float32))
# ('author),', array([0.23020217], dtype=float32))
# ('leading', array([0.23012334], dtype=float32))
# ('core', array([0.22920454], dtype=float32))
# ('solution', array([0.22906558], dtype=float32))
# ('mit', array([0.22815827], dtype=float32))
# ('with', array([0.22774675], dtype=float32))
# ('bachelor', array([0.22703932], dtype=float32))
# ('accumulated', array([0.2251328], dtype=float32))
# ('r/python', array([0.22394222], dtype=float32))
# ('selenium', array([0.22373898], dtype=float32))
# ('amazon', array([0.22325553], dtype=float32))
# ('video', array([0.22277348], dtype=float32))
# ('product', array([0.22269933], dtype=float32))
# ('rate', array([0.21986145], dtype=float32))
# ('oﬀer', array([0.21876894], dtype=float32))
# ('procreate', array([0.21848857], dtype=float32))
# ('intern', array([0.21833111], dtype=float32))
# ('team;', array([0.21730514], dtype=float32))
# ('aug.', array([0.2159546], dtype=float32))
# ('beautifulsoup', array([0.21498951], dtype=float32))
# ('|', array([0.21303542], dtype=float32))
# ('desk', array([0.21191682], dtype=float32))
# ('apply', array([0.21081822], dtype=float32))
# ('parents', array([0.21001537], dtype=float32))
# ('by', array([0.20952119], dtype=float32))
# ('coursework:', array([0.20923284], dtype=float32))
# ('improve', array([0.20766503], dtype=float32))
# ('2017', array([0.20647757], dtype=float32))
# ('like', array([0.20584492], dtype=float32))
# ('urban', array([0.20509203], dtype=float32))
# ('squarespace', array([0.20465024], dtype=float32))
# ('graybiel', array([0.20353833], dtype=float32))
# ('implemented', array([0.20251432], dtype=float32))
# ('towards', array([0.20231168], dtype=float32))
# ('envelope', array([0.20209302], dtype=float32))
# ('schools;', array([0.20195647], dtype=float32))
# ('html/css,', array([0.20181544], dtype=float32))
# ('ca', array([0.19942315], dtype=float32))
# ('may', array([0.19922656], dtype=float32))
# ('top', array([0.19918428], dtype=float32))
# ('microbe', array([0.19694611], dtype=float32))
# ('mentored', array([0.19641808], dtype=float32))
# ('present', array([0.19633918], dtype=float32))
# ('obsidian', array([0.1951683], dtype=float32))
# ('outreach', array([0.19453695], dtype=float32))
# ('pre-med', array([0.19424343], dtype=float32))
# ('resolve,', array([0.1938488], dtype=float32))
# ('us', array([0.193833], dtype=float32))
# ('boosted', array([0.19241366], dtype=float32))
# ('miro,', array([0.19167514], dtype=float32))
# ('college', array([0.1908751], dtype=float32))
# ('channel', array([0.19046055], dtype=float32))
# ('expand', array([0.19013144], dtype=float32))
# ('docs,', array([0.1889733], dtype=float32))
# ('500', array([0.18839312], dtype=float32))
# ('–', array([0.1881779], dtype=float32))
# ('made', array([0.18796912], dtype=float32))
# ('streamline', array([0.18719678], dtype=float32))
# ('commonintern', array([0.18630154], dtype=float32))
# ('figma', array([0.1857532], dtype=float32))
# ('front', array([0.18501998], dtype=float32))
# ('3', array([0.18490753], dtype=float32))
# ('the', array([0.1845014], dtype=float32))
# ('in', array([0.184342], dtype=float32))
# ('phone-alt', array([0.18247157], dtype=float32))
# ('github;', array([0.18170002], dtype=float32))
# ('(@harshibar', array([0.18104053], dtype=float32))
# ('glassdoor', array([0.18087715], dtype=float32))
# ('sponsorships', array([0.17994177], dtype=float32))
# (':', array([0.17988145], dtype=float32))
# ('youtube;', array([0.17783712], dtype=float32))
# ('github', array([0.17773387], dtype=float32))
# ('via', array([0.17756528], dtype=float32))
# ('success', array([0.175623], dtype=float32))
# ('students', array([0.17474309], dtype=float32))
# ('built', array([0.17282005], dtype=float32))
# ('skillshare', array([0.1725641], dtype=float32))
# ('figma,', array([0.17212002], dtype=float32))
# ('10', array([0.17158066], dtype=float32))
# ('notion', array([0.17058767], dtype=float32))
# ('new', array([0.16922034], dtype=float32))
# ('jira,', array([0.16838244], dtype=float32))
# ('return', array([0.16786411], dtype=float32))
# ('review,', array([0.16778438], dtype=float32))
# ('@harshibar', array([0.16772325], dtype=float32))
# ('conducted', array([0.16670603], dtype=float32))
# ('hyku', array([0.1660468], dtype=float32))
# ('shadowed', array([0.16579068], dtype=float32))
# ('scratch', array([0.16490786], dtype=float32))
# ('boarding', array([0.16426049], dtype=float32))
# ('setup', array([0.16423686], dtype=float32))
# ('san', array([0.16365588], dtype=float32))
# ('subscribers', array([0.16316436], dtype=float32))
# ('obs', array([0.16288665], dtype=float32))
# ('spearheaded', array([0.16248818], dtype=float32))
# ('one', array([0.16205077], dtype=float32))
# ('to', array([0.16022454], dtype=float32))
# ('dashboard', array([0.15863463], dtype=float32))
# ('github,', array([0.15858886], dtype=float32))
# ('@harshibar)', array([0.15804201], dtype=float32))
# ('their', array([0.15723753], dtype=float32))
# ('changes', array([0.15574707], dtype=float32))
# ('555.555.5555', array([0.15370591], dtype=float32))
# ('featured', array([0.1531856], dtype=float32))
# ('created', array([0.15242974], dtype=float32))
# ('annually', array([0.15215869], dtype=float32))
# ('pack', array([0.15159728], dtype=float32))
# ('eﬃciency;', array([0.14948444], dtype=float32))
# ('2014', array([0.14870301], dtype=float32))
# ('worked', array([0.14700934], dtype=float32))
# ('rebuilt', array([0.14693937], dtype=float32))
# ('highlights:', array([0.14678401], dtype=float32))
# ('minimal', array([0.14677092], dtype=float32))
# ('blood', array([0.14635313], dtype=float32))
# ('verily', array([0.14578333], dtype=float32))
# ('marketed', array([0.14280511], dtype=float32))
# ('grew', array([0.14234963], dtype=float32))
# ('francisco,', array([0.13935125], dtype=float32))
# ('(postgresql,', array([0.13867582], dtype=float32))
# ('100+', array([0.13799833], dtype=float32))
# ('page', array([0.13771681], dtype=float32))
# ('for', array([0.1365636], dtype=float32))
# ('increased', array([0.1364642], dtype=float32))
# ('(published', array([0.13503613], dtype=float32))
# ('review', array([0.13330564], dtype=float32))
# ('40%', array([0.13026069], dtype=float32))
# ('100%', array([0.13023053], dtype=float32))
# ('harshibar', array([0.12967229], dtype=float32))
# ('stakeholders,', array([0.12962751], dtype=float32))
# ('increase', array([0.12916626], dtype=float32))
# ('$1m', array([0.12882994], dtype=float32))
# ('gumroad', array([0.12879579], dtype=float32))
# ('ma', array([0.12841462], dtype=float32))
# ('full-time', array([0.12771274], dtype=float32))
# ('years;', array([0.12665564], dtype=float32))
# ('early-stage', array([0.12651624], dtype=float32))
# ('sept.', array([0.12640156], dtype=float32))
# ('(react.js),', array([0.12527576], dtype=float32))
# ('partnered', array([0.12465723], dtype=float32))
# ('months', array([0.11992951], dtype=float32))
# ('on', array([0.1197813], dtype=float32))
# ('achieved', array([0.11933585], dtype=float32))
# ('80+', array([0.11884829], dtype=float32))
# ('cross-functional', array([0.11838119], dtype=float32))
# ('hello@email.com', array([0.11780494], dtype=float32))
# ('20%', array([0.10992307], dtype=float32))
# ('15', array([0.1094814], dtype=float32))
# ('shipped', array([0.10704798], dtype=float32))
# ('wellesley', array([0.10620268], dtype=float32))
# ('50k', array([0.10527421], dtype=float32))
# ('thumbnails;', array([0.10476348], dtype=float32))
# ('released', array([0.10461883], dtype=float32))
# ('map-marker-alt', array([0.10361367], dtype=float32))
# ('and', array([0.10067149], dtype=float32))
# ('spread)', array([0.09861093], dtype=float32))
# ('series-related', array([0.09664749], dtype=float32))
# ('not-so-minimal', array([0.09472732], dtype=float32))
# ('20', array([0.0942704], dtype=float32))
# ('u.s.', array([0.09390986], dtype=float32))
# ('2m+', array([0.09101018], dtype=float32))
# ('over', array([0.08978289], dtype=float32))
# ('seattle,', array([0.083278], dtype=float32))
# ('$250', array([0.08261471], dtype=float32))
# ('wellesley,', array([0.0819649], dtype=float32))
# ('60k', array([0.07466057], dtype=float32))
# ('received', array([0.06469303], dtype=float32))
# ('2.5m', array([0.06322294], dtype=float32))
# ('1.5', array([0.04393084], dtype=float32))
# 'out_put_resume2.pdf'
